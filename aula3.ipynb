# %% [markdown]
# ### Music IA Education
# #### Coleta de Dados
# - Questionário via Google Forms
# - Perguntas sobre a faixa etária ,professor e estilo músical.

# %% [markdown]
# ### Objetivo do Experimento
#
# - Criar músicas com ritmos e estiloa músicais adequados para uma turma especifica.
# - As músicas tem objetivo de auxiliar o professor com o recurso didático, sendo que as letras da canções abordarão o contrúdo ministrado pelo professor.
# - As músicas serão geradas por IA no software SUNO e disponibilizado em forma de link.

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/Pesquisa_Eda2.csv')

# %%
df.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [rap]  Avalie os estilos musicais [mpb]  \
# 0                                 1                                 1
# 1                                 3                                 5
# 2                                 5                                 1
# 3                                 5                                 4
# 4                                 4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# 1                                    2                                  1
# 2                                    1                                  1
# 3                                    4                                  4
# 4                                    4                                  1
#
#    Avalie os estilos musicais [sertanejo]  \
# 0                                       1
# 1                                       3
# 2                                       1
# 3                                       1
# 4                                       1
#
#    Avalie os estilos musicais [gospel]  \
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    2
#
#    Avalie os estilos musicais [eletrônica] Qual professor  \
# 0                                        3            NaN
# 1                                        5            NaN
# 2                                        5            NaN
# 3                                        5            NaN
# 4                                        5            NaN
#
#   Qual sua faixa etária  Avalie os estilos musicais [samba]  \
# 0                   NaN                                 NaN
# 1                   NaN                                 NaN
# 2                   NaN                                 NaN
# 3                   NaN                                 NaN
# 4                   NaN                                 NaN
#
#    Avalie os estilos musicais [forró]  Avalie os estilos musicais [trap]  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
#   Digite uma palavra-chave do seu curso que pode ser incluída na música gerada por inteligência artificial?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.columns = ['data/hora','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica','professor','faixa_etaria','samba','forro','trap','palavras']

# %%
df.head(10)
# Out:
#              data/hora  rock  hiphop  mpb  reggae  funk  sertanejo  gospel  \
# 0  21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1  21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2  21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3  21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4  21/08/2024 10:04:55     5       4    3       4     1          1       2
# 5  21/08/2024 10:05:26     5       2    2       2     1          1       2
# 6  21/08/2024 10:05:41     2       4    4       1     4          4       1
# 7  21/08/2024 10:06:14     5       3    3       3     1          2       3
# 8  21/08/2024 10:07:16     4       4    4       1     4          4       1
# 9  21/08/2024 10:07:26     5       5    1       3     4          1       1
#
#    eletronica professor faixa_etaria  samba  forro  trap palavras
# 0           3       NaN          NaN    NaN    NaN   NaN      NaN
# 1           5       NaN          NaN    NaN    NaN   NaN      NaN
# 2           5       NaN          NaN    NaN    NaN   NaN      NaN
# 3           5       NaN          NaN    NaN    NaN   NaN      NaN
# 4           5       NaN          NaN    NaN    NaN   NaN      NaN
# 5           4       NaN          NaN    NaN    NaN   NaN      NaN
# 6           3       NaN          NaN    NaN    NaN   NaN      NaN
# 7           4       NaN          NaN    NaN    NaN   NaN      NaN
# 8           4       NaN          NaN    NaN    NaN   NaN      NaN
# 9           3       NaN          NaN    NaN    NaN   NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data/hora     150 non-null    object
#  1   rock          150 non-null    int64
#  2   hip hop       150 non-null    int64
#  3   mpb           150 non-null    int64
#  4   reggae        150 non-null    int64
#  5   funk          150 non-null    int64
#  6   sertanejo     150 non-null    int64
#  7   gospel        150 non-null    int64
#  8   eletronica    150 non-null    int64
#  9   professor     112 non-null    object
#  10  faixa_etaria  112 non-null    object
#  11  samba         53 non-null     float64
#  12  forro         53 non-null     float64
#  13  trap          53 non-null     float64
#  14  palavras      46 non-null     object
# dtypes: float64(3), int64(8), object(4)
# memory usage: 17.7+ KB

# %%
df.describe()
#estaticas
# Out:
#              rock     hip hop         mpb      reggae        funk   sertanejo  \
# count  150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     3.226667    2.993333    3.046667    2.473333    2.466667    2.873333
# std      1.537656    1.494943    1.480689    1.393642    1.513548    1.453054
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000    1.250000    2.000000    1.000000    1.000000    1.250000
# 50%      3.000000    3.000000    3.000000    2.000000    2.000000    3.000000
# 75%      5.000000    4.000000    4.000000    3.000000    4.000000    4.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#            gospel  eletronica      samba      forro       trap
# count  150.000000  150.000000  53.000000  53.000000  53.000000
# mean     2.620000    3.273333   2.698113   2.773585   3.283019
# std      1.504668    1.518992   1.380982   1.280648   1.548912
# min      1.000000    1.000000   1.000000   1.000000   1.000000
# 25%      1.000000    2.000000   1.000000   2.000000   2.000000
# 50%      2.000000    4.000000   3.000000   3.000000   4.000000
# 75%      4.000000    5.000000   4.000000   4.000000   5.000000
# max      5.000000    5.000000   5.000000   5.000000   5.000000

# %%
colunas = ['rock', 'hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica',]
condicao = df['professor'] == 'Karython'
df_filtrado = df[condicao]

# %%
soma = df_filtrado[colunas].mean()

# %%
soma.plot(kind='barh', colormap='plasma', title='Pesquisa musical turma do Karython')
# Out:
# <Axes: title={'center': 'Pesquisa musical turma do Karython'}>

# %% [markdown]
#     '
