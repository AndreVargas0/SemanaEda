# %% [markdown]
# # Pesquisa de  Gênero musical favorito Senai.

# %% [markdown]
# Objetivo: usar a inteligência artificial na sala de aula, gerando músicas nerds com ritmos que os alunos terão uma experiência imersiva na aula.

# %%
import pandas as pd

# %%
url = "dataset\Pesquisa.csv" 
pd.read_csv(url)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ead\AppData\Local\Temp\ipykernel_12112\3420896561.py:1: SyntaxWarning: invalid escape sequence '\P'
#   url = "dataset\Pesquisa.csv"
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0   21/08/2024 10:03:25                                  3
# 1   21/08/2024 10:04:39                                  5
# 2   21/08/2024 10:04:52                                  1
# 3   21/08/2024 10:04:53                                  1
# 4   21/08/2024 10:04:55                                  5
# 5   21/08/2024 10:05:26                                  5
# 6   21/08/2024 10:05:41                                  2
# 7   21/08/2024 10:06:14                                  5
# 8   21/08/2024 10:07:16                                  4
# 9   21/08/2024 10:07:26                                  5
# 10  21/08/2024 10:07:31                                  3
# ...

# %%
df = pd.read_csv(url)

# %%
df = df.drop(columns=['Carimbo de data/hora'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df = df.drop(columns=['Carimbo de data/hora'])
#
# File c:\Users\ead\Desktop\André Luiz\semanaeda\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
pd.read_csv(url)
# Out:
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0   21/08/2024 10:03:25                                  3
# 1   21/08/2024 10:04:39                                  5
# 2   21/08/2024 10:04:52                                  1
# 3   21/08/2024 10:04:53                                  1
# 4   21/08/2024 10:04:55                                  5
# 5   21/08/2024 10:05:26                                  5
# 6   21/08/2024 10:05:41                                  2
# 7   21/08/2024 10:06:14                                  5
# 8   21/08/2024 10:07:16                                  4
# 9   21/08/2024 10:07:26                                  5
# 10  21/08/2024 10:07:31                                  3
# 11  21/08/2024 10:08:37                                  4
# 12  21/08/2024 10:38:46                                  5
# 13  21/08/2024 10:58:52                                  5
#
#     Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# ...

# %%
df.columns=['rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletrônica']

# %%
df
# Out:
#     rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletrônica
# 0      3       1    1       1     1          1       1           3
# 1      5       3    5       2     1          3       1           5
# 2      1       5    1       1     1          1       1           5
# 3      1       5    4       4     4          1       1           5
# 4      5       4    3       4     1          1       2           5
# 5      5       2    2       2     1          1       2           4
# 6      2       4    4       1     4          4       1           3
# 7      5       3    3       3     1          2       3           4
# 8      4       4    4       1     4          4       1           4
# 9      5       5    1       3     4          1       1           3
# 10     3       2    5       4     3          4       4           2
# 11     4       1    5       1     1          2       5           1
# 12     5       1    3       1     1          1       1           4
# ...

# %%
import seaborn as sns

# %%
sns.boxenplot(rock)
